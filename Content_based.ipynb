# %%
import numpy as np #linear algebra
import pandas as pd #for data processing

# %% [markdown]
# importing csv file

# %%
df_movies = pd.read_csv('tmdb_5000_movies.csv')

# %% [markdown]
# Displaying the datasets

# %%
df_movies.head(4)

# %% [markdown]
# Displaying the overview column

# %%
df_movies['overview']

# %% [markdown]
# Sklearn and TF-IDF vectorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# Develope TF-IDF.
# Extract all the words that are required, words with most importance.
# create vector space model.
# Based on cosine similarity recommendation is generated.

# %% [markdown]
# stop words meaning word having no meanings
# eg: the, is, then, but etc

# %%
tfidf = TfidfVectorizer(stop_words = "english")
df_movies['overview'] = df_movies['overview'].fillna("")

# %% [markdown]
# Vector space model or Tfidf vector

# %%
tfidf_matrix = tfidf.fit_transform(df_movies['overview'])

# %%
from sklearn.metrics.pairwise import linear_kernel

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %% [markdown]
# extracting indixes and movie name

# %%
indices = pd.Series(df_movies.index, index = df_movies['original_title']).drop_duplicates()
indices

# %%
  indices['The Dark Knight Rises']
# Out:
# 3

# %% [markdown]
# Getting Recommendation

# %%
def get_recommendations(title, cosine_sim = cosine_sim):

  idx = indices[title]
  sim_scores = enumerate(cosine_sim[idx])

  sim_scores = sorted(sim_scores,key = lambda x: x[1], reverse=True)
  sim_scores = sim_scores[1:11]

  sim_index = [i[0] for i in sim_scores]
  print(sim_index)

  print(df_movies["original_title"].iloc[sim_index])

get_recommendations('The Dark Knight Rises')

# %% [markdown]
# Training model

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load the dataset
df = pd.read_csv('tmdb_5000_movies.csv')

# %%
# Replace NaN values with empty strings
df['overview'] = df['overview'].fillna('')

# %%
# Create the tf-idf vectorizer object
tfidf_vectorizer = TfidfVectorizer()

# %%
# Fit the vectorizer object to the dataset
tfidf_matrix = tfidf_vectorizer.fit_transform(df['overview'])

# %%
# Compute the cosine similarity matrix
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
print(cosine_sim)

# %%
# Save the cosine similarity matrix to a file
pd.DataFrame(cosine_sim).to_csv('cosine_similarity_matrix.csv', index=False)

# %%
# Print the cosine similarity matrix
print(pd.DataFrame(cosine_sim))

# %%
# Get the index of the movie that we want to recommend movies similar to
movie_index = 0

# %%
# Get the pairwise similarity scores of all movies with that movie
similarity_scores = list(enumerate(cosine_sim[movie_index]))

# %%
print(similarity_scores)

# %%
# Sort the movies based on the similarity scores
sorted_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)

# %%
print(sorted_scores)

# %%
# Get the movie indices of the top similar movies
top_indices = [i[0] for i in sorted_scores[1:6]] # Top 5 similar movies

# %%
# Print the top similar movies
print(df['title'].iloc[top_indices])

# %% [markdown]
# this code take movie title as input

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Load the dataset
df = pd.read_csv('tmdb_5000_movies.csv')

# Replace NaN values with empty strings
df['overview'] = df['overview'].fillna('')

# Create the tf-idf vectorizer object
tfidf_vectorizer = TfidfVectorizer()

# Fit the vectorizer object to the dataset
tfidf_matrix = tfidf_vectorizer.fit_transform(df['overview'])

# Get user input for the movie title
movie_title = input('Enter the title of the movie: ')

# Get the index of the movie with the specified title
movie_index = df[df['title'] == movie_title].index.values[0]

# Get the pairwise similarity scores of all movies with that movie
similarity_scores = list(enumerate(cosine_sim[movie_index]))

# Sort the movies based on the similarity scores
sorted_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)

# Get the movie indices of the top similar movies
top_indices = [i[0] for i in sorted_scores[1:6]] # Top 5 similar movies

# Print the top similar movies
print(df['title'].iloc[top_indices])
# Out:
# Enter the title of the movie: The Dark Knight Rises
# 65                              The Dark Knight
# 299                              Batman Forever
# 428                              Batman Returns
# 1359                                     Batman
# 3854    Batman: The Dark Knight Returns, Part 2
# Name: title, dtype: object
